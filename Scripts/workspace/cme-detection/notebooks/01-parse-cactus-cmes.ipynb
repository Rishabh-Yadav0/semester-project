# %% [markdown]
# This notebook demonstrates the CME occurrences in our timeline.

# %% [markdown]
# Setting the absolute path at the root directory of the repo.

# %%
import sysimport ossys.path.append(os.path.abspath('../scripts'))

# %% [markdown]
# Importing the required methods from cactus handler script.

# %%
from load_plot_cactus_data import parse_cactus_file, plot_cme

# %% [markdown]
# Loading in the data from the Cactus text files.

# %%
cme_times = (parse_cactus_file('../data/cmesept2024.txt') +              parse_cactus_file('../data/cmeoct2024.txt') +              parse_cactus_file('../data/cmenov2024.txt') +             parse_cactus_file('../data/cmedec2024.txt') +             parse_cactus_file('../data/cmejan2025.txt') +             parse_cactus_file('../data/cmefeb2025.txt') +             parse_cactus_file('../data/cmemar2025.txt') +             parse_cactus_file('../data/cmeapril2025.txt')            )

# %% [markdown]
# Generating the graph:

# %%
plot_cme(cme_times)
